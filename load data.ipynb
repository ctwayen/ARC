# %%
import json
import os
import matplotlib.pyplot as plt
import numpy as np

train_dir = 'data/training'

# %% [markdown]
# https://www.kaggle.com/c/abstraction-and-reasoning-challenge/data
#
# data description

# %%
train = []
test = []

# %%
for file in os.listdir(train_dir):
    with open(os.path.join(train_dir, file)) as f:
        temp = json.load(f)
        train.append(temp['train'])
        test.append(temp['test'])

# %%
train_input = []
train_output = []
for task in train:
    inputs = []
    outputs = []
    for pairs in task:
        inputs.append(pairs['input'])
        outputs.append(pairs['output'])
    train_input.append(inputs)
    train_output.append(outputs)
test_input = []
test_output = []
for task in test:
    for pairs in task:
        test_input.append(pairs['input'])
        test_output.append(pairs['output'])
# Out:
# array([0, 7])
# array([0, 4])
# array([0, 2])
# array([0, 6])
# array([0, 2])
# array([0, 3])
# array([0, 3])
# array([0, 3])
# array([0, 3])
# array([0, 3])
# array([0, 1])
# array([0, 1])
# array([0, 1])
# array([0, 2, 6])
# array([0, 8])
# array([0, 2, 3, 8])
# array([0, 1, 2, 4])
# array([0, 1, 5, 6])
# array([0, 1, 5])
# array([0, 1, 5])
# array([0, 1, 5])
# array([0, 2, 3, 8])
# array([0, 1, 2, 4])
# array([0, 3, 4, 8])
# array([0, 2, 8])
# array([0, 2, 8])
# array([0, 2, 8])
# array([0, 1, 2, 3, 8])
# array([0, 1, 2, 4, 8, 9])
# array([0, 2, 3, 4])
# array([0, 5])
# array([0, 5])
# array([0, 2, 3, 4, 5, 6, 8])
# array([0, 2, 3, 4, 5, 6, 8])
# array([0, 2, 3, 4, 5, 6, 8])
# array([0, 2, 3, 4, 5, 6, 8])
# array([0, 2, 7])
# array([0, 6, 8])
# array([0, 2, 8])
# array([0, 1, 3])
# array([0, 2, 3])
# array([0, 1, 4])
# array([0, 2, 8])
# array([0, 2, 3])
# array([0, 1, 4])
# array([0, 1, 2])
# array([0, 1, 2, 8])
# array([0, 1, 2, 6])
# array([1, 2, 3])
# array([2, 3, 8])
# ...

# %%
def display_task(index):
    inputs = train_input[index]
    outputs = train_output[index]
    size = len(inputs)
    fig, ax = plt.subplots(2, size+1, figsize=(4*size, 8))
    for i in range(size): 
        ax[0][i].imshow(inputs[i])
        ax[0][i].set_title('{i} train input'.format(i=i))
        ax[1][i].imshow(outputs[i])
        ax[1][i].set_title('{i} train output'.format(i=i))
    ax[0][size].imshow(test_input[index])
    ax[0][size].set_title('test input')
    ax[1][size].imshow(test_output[index])
    ax[1][size].set_title('test output')

# %%
display_task(0)

# %%
plt.imshow(train_input[0][0])

# %%
train_input[0][0]
# Out:
# [[0, 7, 7], [7, 7, 7], [0, 7, 7]]

# %%
plt.imshow(train_output[1][0])

# %%
np.array(train_input)[0]
# Out:
# [[4, 0, 4], [0, 0, 0], [0, 4, 0]]

# %%
train_input.asarray
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-dbdedece834a> in <module>
# ----> 1 train_input.asarray
#
# AttributeError: 'list' object has no attribute 'asarray'

# %%
display_task(1)

# %%
display_task(2)

# %%
for i in range(3, 10):
    display_task(i)

# %%
for i in range(11, 21):
    display_task(i)

# %%
len(train_input)
# Out:
# 400

# %%
for i in range(21, 31):
    display_task(i)
